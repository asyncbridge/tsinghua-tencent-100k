# %%
import json
import pylab as pl
import random
import numpy as np
import cv2
import anno_func
# %matplotlib inline

# %%
datadir = "../../data/"

filedir = datadir + "/annotations.json"
ids = open(datadir + "/test/ids.txt").read().splitlines()

annos = json.loads(open(filedir).read())

# %%
#imgid = random.sample(ids, 1)[0]
imgid = '88023'
print imgid

imgdata = anno_func.load_img(annos, datadir, imgid)
imgdata_draw = anno_func.draw_all(annos, datadir, imgid, imgdata)
pl.figure(figsize=(10,10))
pl.imshow(imgdata_draw)
# Out:
# 88023
# ((90.73252868652344, 901.6370239257812), (17.76877212524414, 29.06221580505371), 169.4116973876953)
# ((169.7040252685547, 895.56494140625), (20.567501068115234, 33.33624267578125), 2.200296640396118)
# ((359.4248962402344, 923.4368286132812), (19.130390167236328, 21.36089515686035), 170.4455108642578)
# ((378.4187316894531, 921.8139038085938), (18.878572463989258, 25.64341163635254), 11.51158332824707)
