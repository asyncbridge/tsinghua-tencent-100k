# %%
import json
import pylab as pl
import random
import numpy as np
import cv2
import anno_func
# %matplotlib inline

# %%
datadir = ".."

filedir = datadir + "/annotations.json"
ids = open(datadir + "/test/ids.txt").read().splitlines()

annos = json.loads(open(filedir).read())

# %%
imgid = random.sample(ids, 1)[0]
print imgid

imgdata = anno_func.load_img(annos, datadir, imgid)
imgdata_draw = anno_func.draw_all(annos, datadir, imgid, imgdata)
pl.figure(figsize=(20,20))
pl.imshow(imgdata_draw)
# Out:
# 18011013130312101750800_front
# ((580.7587280273438, 408.5700378417969), (92.29686737060547, 112.64171600341797), 65.85820770263672)
# ((713.0161743164062, 391.5760803222656), (97.65657806396484, 116.55596923828125), 68.01317596435547)
# ((962.8947143554688, 377.79547119140625), (97.92916107177734, 126.287353515625), 86.32988739013672)
# ((582.3129272460938, 520.566650390625), (103.2007064819336, 111.08224487304688), 75.87767791748047)
# ((712.8544311523438, 505.58795166015625), (101.07752990722656, 119.2708740234375), 64.76689147949219)
# ((960.979248046875, 492.87109375), (104.05765533447266, 130.546630859375), 80.96044158935547)
# ((1103.7784423828125, 493.2060241699219), (103.50924682617188, 124.7997055053711), 85.81426239013672)
# ((1330.2545166015625, 501.70166015625), (102.56732177734375, 116.60450744628906), 97.95067596435547)
# ((1463.370361328125, 514.475830078125), (100.08631896972656, 112.0562744140625), 129.6671142578125)
# ((1680.3863525390625, 543.5253295898438), (91.43121337890625, 101.05585479736328), 143.88037109375)
# ((1786.312255859375, 564.3273315429688), (82.38610076904297, 97.31761169433594), 152.488525390625)
# ((1962.0216064453125, 608.0894775390625), (67.13336181640625, 88.59835815429688), 159.23098754882812)
